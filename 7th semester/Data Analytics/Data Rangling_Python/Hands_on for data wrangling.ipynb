# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from matplotlib import pyplot

# %%
path = '/Users/maik/Documents/DCSE/Courses/Data Analytics/Hands_On/autos.csv'

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    normalized-losses         make fuel-type aspiration num-of-doors  \
# 0                NaN  alfa-romero       gas        std          two
# 1                NaN  alfa-romero       gas        std          two
# 2                NaN  alfa-romero       gas        std          two
# 3              164.0         audi       gas        std         four
# 4              164.0         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  ...  \
# 0  convertible          rwd           front        88.6   168.8  ...
# 1  convertible          rwd           front        88.6   168.8  ...
# 2    hatchback          rwd           front        94.5   171.2  ...
# 3        sedan          fwd           front        99.8   176.6  ...
# 4        sedan          4wd           front        99.4   176.6  ...
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# ...

# %%
df.isnull()
# Out:
#      normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0                 True  False      False       False         False
# 1                 True  False      False       False         False
# 2                 True  False      False       False         False
# 3                False  False      False       False         False
# 4                False  False      False       False         False
# ..                 ...    ...        ...         ...           ...
# 200              False  False      False       False         False
# 201              False  False      False       False         False
# 202              False  False      False       False         False
# 203              False  False      False       False         False
# 204              False  False      False       False         False
#
#      body-style  drive-wheels  engine-location  wheel-base  length  ...  \
# 0         False         False            False       False   False  ...
# ...

# %%
missingData = df.isnull()

# %%
missingData
# Out:
#      normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0                 True  False      False       False         False
# 1                 True  False      False       False         False
# 2                 True  False      False       False         False
# 3                False  False      False       False         False
# 4                False  False      False       False         False
# ..                 ...    ...        ...         ...           ...
# 200              False  False      False       False         False
# 201              False  False      False       False         False
# 202              False  False      False       False         False
# 203              False  False      False       False         False
# 204              False  False      False       False         False
#
#      body-style  drive-wheels  engine-location  wheel-base  length  ...  \
# 0         False         False            False       False   False  ...
# ...

# %%
for col in missingData.columns.values.tolist():
    print(col)
    print(missingData[col].value_counts())
    print("")
# Out:
# normalized-losses
# False    164
# True      41
# Name: normalized-losses, dtype: int64
#
# make
# False    205
# Name: make, dtype: int64
#
# fuel-type
# False    205
# Name: fuel-type, dtype: int64
#
# aspiration
# False    205
# Name: aspiration, dtype: int64
#
# num-of-doors
# False    203
# True       2
# Name: num-of-doors, dtype: int64
#
# body-style
# False    205
# Name: body-style, dtype: int64
#
# drive-wheels
# False    205
# Name: drive-wheels, dtype: int64
#
# engine-location
# False    205
# Name: engine-location, dtype: int64
#
# wheel-base
# False    205
# Name: wheel-base, dtype: int64
#
# length
# False    205
# Name: length, dtype: int64
#
# width
# False    205
# Name: width, dtype: int64
#
# height
# False    205
# Name: height, dtype: int64
#
# curb-weight
# False    205
# Name: curb-weight, dtype: int64
#
# engine-type
# False    205
# Name: engine-type, dtype: int64
#
# num-of-cylinders
# False    205
# Name: num-of-cylinders, dtype: int64
#
# engine-size
# ...

# %%
df.replace(np.NaN,'?',inplace=True)

# %%
df.to_csv('/Users/maik/Documents/DCSE/Courses/Data Analytics/Hands_On/autos_new.csv')

# %%
df
# Out:
#     normalized-losses         make fuel-type aspiration num-of-doors  \
# 0                   ?  alfa-romero       gas        std          two
# 1                   ?  alfa-romero       gas        std          two
# 2                   ?  alfa-romero       gas        std          two
# 3                 164         audi       gas        std         four
# 4                 164         audi       gas        std         four
# ..                ...          ...       ...        ...          ...
# 200                95        volvo       gas        std         four
# 201                95        volvo       gas      turbo         four
# 202                95        volvo       gas        std         four
# 203                95        volvo    diesel      turbo         four
# 204                95        volvo       gas      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base  length  ...  \
# ...

# %%
df.replace('?',np.NaN,inplace=True)

# %%
df
# Out:
#      normalized-losses         make fuel-type aspiration num-of-doors  \
# 0                  NaN  alfa-romero       gas        std          two
# 1                  NaN  alfa-romero       gas        std          two
# 2                  NaN  alfa-romero       gas        std          two
# 3                164.0         audi       gas        std         four
# 4                164.0         audi       gas        std         four
# ..                 ...          ...       ...        ...          ...
# 200               95.0        volvo       gas        std         four
# 201               95.0        volvo       gas      turbo         four
# 202               95.0        volvo       gas        std         four
# 203               95.0        volvo    diesel      turbo         four
# 204               95.0        volvo       gas      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base  length  ...  \
# ...

# %%
avg_norm_loss = df['normalized-losses'].mean()
print(avg_norm_loss)
# Out:
# 122.0

# %%
df['normalized-losses'].replace(np.NaN,avg_norm_loss,inplace=True)

# %%
avg_stroke = df['stroke'].mean()
print(avg_stroke)
# Out:
# 3.2554228855721337

# %%
df['stroke'].replace(np.NaN,avg_stroke,inplace=True)

# %%
df
# Out:
#      normalized-losses         make fuel-type aspiration num-of-doors  \
# 0                122.0  alfa-romero       gas        std          two
# 1                122.0  alfa-romero       gas        std          two
# 2                122.0  alfa-romero       gas        std          two
# 3                164.0         audi       gas        std         four
# 4                164.0         audi       gas        std         four
# ..                 ...          ...       ...        ...          ...
# 200               95.0        volvo       gas        std         four
# 201               95.0        volvo       gas      turbo         four
# 202               95.0        volvo       gas        std         four
# 203               95.0        volvo    diesel      turbo         four
# 204               95.0        volvo       gas      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base  length  ...  \
# ...

# %%
freq = df['num-of-doors'].value_counts().idxmax()

# %%
freq
# Out:
# 'four'

# %%
df['num-of-doors'].replace(np.NaN, freq, inplace=True)

# %%
df['num-of-doors']
# Out:
# 0       two
# 1       two
# 2       two
# 3      four
# 4      four
#        ...
# 200    four
# 201    four
# 202    four
# 203    four
# 204    four
# Name: num-of-doors, Length: 205, dtype: object

# %%
avg_bore = df['bore'].mean()
print(avg_bore)
# Out:
# 3.3297512437810957

# %%
df['bore'].replace(np.NaN,avg_bore,inplace=True)

# %%
avg_horsepower = df['horsepower'].astype(float,copy=True).mean()

# %%
avg_horsepower
# Out:
# 104.25615763546799

# %%
df['horsepower'].replace(np.NaN,avg_horsepower,inplace=True)

# %%
avg_rpm = df['peak-rpm'].astype(float).mean()

# %%
avg_rpm
# Out:
# 5125.369458128079

# %%
df['peak-rpm'].replace(np.NaN,avg_rpm,inplace=True)

# %%
for col in df.columns.values.tolist():
    print(col)
    print(df[col].value_counts())
    print("")
# Out:
# normalized-losses
# 122.0    45
# 161.0    11
# 91.0      8
# 150.0     7
# 104.0     6
# 134.0     6
# 128.0     6
# 94.0      5
# 74.0      5
# 85.0      5
# 103.0     5
# 168.0     5
# 95.0      5
# 65.0      5
# 102.0     5
# 148.0     4
# 106.0     4
# 93.0      4
# 118.0     4
# 115.0     3
# 154.0     3
# 125.0     3
# 137.0     3
# 101.0     3
# 83.0      3
# 194.0     2
# 110.0     2
# 145.0     2
# 119.0     2
# 197.0     2
# 108.0     2
# 188.0     2
# 129.0     2
# 81.0      2
# 164.0     2
# 192.0     2
# 158.0     2
# 153.0     2
# 87.0      2
# 89.0      2
# 113.0     2
# 121.0     1
# 98.0      1
# 186.0     1
# 78.0      1
# 107.0     1
# 77.0      1
# 90.0      1
# 256.0     1
# 231.0     1
# 142.0     1
# Name: normalized-losses, dtype: int64
#
# make
# toyota           32
# nissan           18
# mazda            17
# honda            13
# mitsubishi       13
# subaru           12
# volkswagen       12
# volvo            11
# peugot           11
# ...

# %%
missing_data = df.isnull()

# %%
missing_data
# Out:
#      normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0                False  False      False       False         False
# 1                False  False      False       False         False
# 2                False  False      False       False         False
# 3                False  False      False       False         False
# 4                False  False      False       False         False
# ..                 ...    ...        ...         ...           ...
# 200              False  False      False       False         False
# 201              False  False      False       False         False
# 202              False  False      False       False         False
# 203              False  False      False       False         False
# 204              False  False      False       False         False
#
#      body-style  drive-wheels  engine-location  wheel-base  length  ...  \
# 0         False         False            False       False   False  ...
# ...

# %%
for col in missing_data.columns.values.tolist():
    print(col)
    print(missing_data[col].value_counts())
    print("")
# Out:
# normalized-losses
# False    205
# Name: normalized-losses, dtype: int64
#
# make
# False    205
# Name: make, dtype: int64
#
# fuel-type
# False    205
# Name: fuel-type, dtype: int64
#
# aspiration
# False    205
# Name: aspiration, dtype: int64
#
# num-of-doors
# False    205
# Name: num-of-doors, dtype: int64
#
# body-style
# False    205
# Name: body-style, dtype: int64
#
# drive-wheels
# False    205
# Name: drive-wheels, dtype: int64
#
# engine-location
# False    205
# Name: engine-location, dtype: int64
#
# wheel-base
# False    205
# Name: wheel-base, dtype: int64
#
# length
# False    205
# Name: length, dtype: int64
#
# width
# False    205
# Name: width, dtype: int64
#
# height
# False    205
# Name: height, dtype: int64
#
# curb-weight
# False    205
# Name: curb-weight, dtype: int64
#
# engine-type
# False    205
# Name: engine-type, dtype: int64
#
# num-of-cylinders
# False    205
# Name: num-of-cylinders, dtype: int64
#
# engine-size
# False    205
# ...

# %%
df.dropna(subset=['price'],axis=0,inplace=True)

# %%
df.reset_index(inplace=True)

# %%
missing_data=df.isnull()

# %%
for col in missing_data.columns.values.tolist():
    print(col)
    print(missing_data[col].value_counts())
    print("")
# Out:
# index
# False    201
# Name: index, dtype: int64
#
# normalized-losses
# False    201
# Name: normalized-losses, dtype: int64
#
# make
# False    201
# Name: make, dtype: int64
#
# fuel-type
# False    201
# Name: fuel-type, dtype: int64
#
# aspiration
# False    201
# Name: aspiration, dtype: int64
#
# num-of-doors
# False    201
# Name: num-of-doors, dtype: int64
#
# body-style
# False    201
# Name: body-style, dtype: int64
#
# drive-wheels
# False    201
# Name: drive-wheels, dtype: int64
#
# engine-location
# False    201
# Name: engine-location, dtype: int64
#
# wheel-base
# False    201
# Name: wheel-base, dtype: int64
#
# length
# False    201
# Name: length, dtype: int64
#
# width
# False    201
# Name: width, dtype: int64
#
# height
# False    201
# Name: height, dtype: int64
#
# curb-weight
# False    201
# Name: curb-weight, dtype: int64
#
# engine-type
# False    201
# Name: engine-type, dtype: int64
#
# num-of-cylinders
# False    201
# ...

# %%
df.head(40)
# Out:
#     index  normalized-losses         make fuel-type aspiration num-of-doors  \
# 0       0              122.0  alfa-romero       gas        std          two
# 1       1              122.0  alfa-romero       gas        std          two
# 2       2              122.0  alfa-romero       gas        std          two
# 3       3              164.0         audi       gas        std         four
# 4       4              164.0         audi       gas        std         four
# 5       5              122.0         audi       gas        std          two
# 6       6              158.0         audi       gas        std         four
# 7       7              122.0         audi       gas        std         four
# 8       8              158.0         audi       gas      turbo         four
# 9      10              192.0          bmw       gas        std          two
# 10     11              192.0          bmw       gas        std         four
# ...

# %%
df.dtypes
# Out:
# index                  int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# symboling              int64
# dtype: object

# %%
df['city_L/100Km']=235/df['city-mpg']

# %%
df['highway_L/100Km']=235/df['highway-mpg']

# %%
df.head()
# Out:
#    index  normalized-losses         make fuel-type aspiration num-of-doors  \
# 0      0              122.0  alfa-romero       gas        std          two
# 1      1              122.0  alfa-romero       gas        std          two
# 2      2              122.0  alfa-romero       gas        std          two
# 3      3              164.0         audi       gas        std         four
# 4      4              164.0         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  stroke  \
# 0  convertible          rwd           front        88.6  ...    2.68
# 1  convertible          rwd           front        88.6  ...    2.68
# 2    hatchback          rwd           front        94.5  ...    3.47
# 3        sedan          fwd           front        99.8  ...    3.40
# 4        sedan          4wd           front        99.4  ...    3.40
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
df['length']=df['length']/df['length'].max()
print(df['length'])
# Out:
# 0      0.811148
# 1      0.811148
# 2      0.822681
# 3      0.848630
# 4      0.848630
#          ...
# 196    0.907256
# 197    0.907256
# 198    0.907256
# 199    0.907256
# 200    0.907256
# Name: length, Length: 201, dtype: float64

# %%
df['width']=df['width']/df['width'].max()

# %%
df['height'] = df['height']/df['height'].max()

# %%
df[['length','width','height']]
# Out:
#        length     width    height
# 0    0.811148  0.890278  0.816054
# 1    0.811148  0.890278  0.816054
# 2    0.822681  0.909722  0.876254
# 3    0.848630  0.919444  0.908027
# 4    0.848630  0.922222  0.908027
# ..        ...       ...       ...
# 196  0.907256  0.956944  0.928094
# 197  0.907256  0.955556  0.928094
# 198  0.907256  0.956944  0.928094
# 199  0.907256  0.956944  0.928094
# 200  0.907256  0.956944  0.928094
#
# [201 rows x 3 columns]

# %%
df['horsepower'].dtype
# Out:
# dtype('float64')

# %%
df['horsepower'].astype(int,copy=True)
# Out:
# 0      111
# 1      111
# 2      154
# 3      102
# 4      115
#       ...
# 196    114
# 197    160
# 198    134
# 199    106
# 200    114
# Name: horsepower, Length: 201, dtype: int64

# %%
plt.pyplot.hist(df['horsepower'])
# Out:
# (array([44., 45., 48., 24., 14., 16.,  5.,  4.,  0.,  1.]),
#  array([ 48. ,  69.4,  90.8, 112.2, 133.6, 155. , 176.4, 197.8, 219.2,
#         240.6, 262. ]),
#  <BarContainer object of 10 artists>)

# %%
bins = np.linspace(min(df['horsepower']), max(df['horsepower']),4)

# %%
group_names = ['low','medium','High']

# %%
df['horsepower_binned']=pd.cut(df['horsepower'],bins,labels = group_names)

# %%
df['horsepower_binned'].value_counts()
# Out:
# low       152
# medium     43
# High        5
# Name: horsepower_binned, dtype: int64

# %%
plt.pyplot.hist(df['horsepower'],bins=3)
# Out:
# (array([153.,  43.,   5.]),
#  array([ 48.        , 119.33333333, 190.66666667, 262.        ]),
#  <BarContainer object of 3 artists>)

# %%
df.head()
# Out:
#    index  normalized-losses         make fuel-type aspiration num-of-doors  \
# 0      0              122.0  alfa-romero       gas        std          two
# 1      1              122.0  alfa-romero       gas        std          two
# 2      2              122.0  alfa-romero       gas        std          two
# 3      3              164.0         audi       gas        std         four
# 4      4              164.0         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  \
# 0  convertible          rwd           front        88.6  ...
# 1  convertible          rwd           front        88.6  ...
# 2    hatchback          rwd           front        94.5  ...
# 3        sedan          fwd           front        99.8  ...
# 4        sedan          4wd           front        99.4  ...
#
#    compression-ratio  horsepower  peak-rpm  city-mpg highway-mpg    price  \
# ...

# %%
df.describe()
# Out:
#             index  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean   102.900498          122.00000   98.797015    0.837102    0.915126
# std     59.234956           31.99625    6.066366    0.059213    0.029187
# min      0.000000           65.00000   86.600000    0.678039    0.837500
# 25%     53.000000          101.00000   94.500000    0.801538    0.890278
# 50%    103.000000          122.00000   97.000000    0.832292    0.909722
# 75%    154.000000          137.00000  102.400000    0.881788    0.925000
# max    204.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000
# mean     0.899108  2555.666667   126.875622    3.330692    3.256874
# std      0.040933   517.296727    41.546834    0.268072    0.316048
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              201 non-null    int64
#  1   normalized-losses  201 non-null    float64
#  2   make               201 non-null    object
#  3   fuel-type          201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       201 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
# ...

# %%
df['drive-wheels'].value_counts().to_frame()
# Out:
#      drive-wheels
# fwd           118
# rwd            75
# 4wd             8

# %%
df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df_group_one = df[['drive-wheels','body-style','price']]

# %%
df_group_one
# Out:
#     drive-wheels   body-style    price
# 0            rwd  convertible  13495.0
# 1            rwd  convertible  16500.0
# 2            rwd    hatchback  16500.0
# 3            fwd        sedan  13950.0
# 4            4wd        sedan  17450.0
# ..           ...          ...      ...
# 196          rwd        sedan  16845.0
# 197          rwd        sedan  19045.0
# 198          rwd        sedan  21485.0
# 199          rwd        sedan  22470.0
# 200          rwd        sedan  22625.0
#
# [201 rows x 3 columns]

# %%
df_group_one = df_group_one.groupby(['drive-wheels'],as_index=False).mean()
df_group_one
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %%
df_gptest = df[['drive-wheels','body-style', 'price']]
grouped_test1 = df_gptest.groupby(['drive-wheels','body-style'],as_index=False).mean()

# %%
grouped_test1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
grouped_pivot = grouped_test1.pivot(index='drive-wheels',columns='body-style')
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
PT = pd.pivot_table(df,values='price',index=['body-style','city-mpg'],columns=['drive-wheels'],aggfunc=np.mean)
PT
# Out:
# drive-wheels             4wd      fwd      rwd
# body-style  city-mpg
# convertible 16           NaN      NaN  35056.0
#             17           NaN      NaN  37028.0
#             21           NaN      NaN  14997.5
#             24           NaN  11595.0  17669.0
# hardtop     14           NaN      NaN  45400.0
# ...                      ...      ...      ...
# wagon       25           NaN  11244.0  15467.5
#             27        8338.0      NaN      NaN
#             28           NaN   7463.0      NaN
#             30           NaN   7295.0      NaN
#             31           NaN   7422.0      NaN
#
# [64 rows x 3 columns]

# %%
df
# Out:
#      index  normalized-losses         make fuel-type aspiration num-of-doors  \
# 0        0              122.0  alfa-romero       gas        std          two
# 1        1              122.0  alfa-romero       gas        std          two
# 2        2              122.0  alfa-romero       gas        std          two
# 3        3              164.0         audi       gas        std         four
# 4        4              164.0         audi       gas        std         four
# ..     ...                ...          ...       ...        ...          ...
# 196    200               95.0        volvo       gas        std         four
# 197    201               95.0        volvo       gas      turbo         four
# 198    202               95.0        volvo       gas        std         four
# 199    203               95.0        volvo    diesel      turbo         four
# 200    204               95.0        volvo       gas      turbo         four
#
# ...

# %%
df.corr()
# Out:
#                       index  normalized-losses  wheel-base    length  \
# index              1.000000          -0.241034    0.125728  0.162374
# normalized-losses -0.241034           1.000000   -0.056661  0.019424
# wheel-base         0.125728          -0.056661    1.000000  0.876024
# length             0.162374           0.019424    0.876024  1.000000
# width              0.044613           0.086802    0.814507  0.857170
# height             0.251376          -0.373737    0.590742  0.492063
# curb-weight        0.065501           0.099404    0.782097  0.880665
# engine-size       -0.046752           0.112360    0.572027  0.685025
# bore               0.246473          -0.029862    0.493244  0.608971
# stroke            -0.162926           0.055045    0.158018  0.123952
# compression-ratio  0.144770          -0.114713    0.250313  0.159733
# horsepower        -0.022434           0.217299    0.371147  0.579821
# peak-rpm          -0.198430           0.239543   -0.360305 -0.285970
# ...

# %%
from scipy import stats

# %%
pearson_coef, p_value = stats.pearsonr(df['wheel-base'],df['price'])
print((pearson_coef,p_value))
# Out:
# (0.584641822265508, 8.076488270733218e-20)
